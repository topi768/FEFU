# %%
import vitaldb
import plotly.express as px

import pandas as pd

# %%
vf = vitaldb.VitalFile("0010.vital").to_pandas(['Solar8000/BT', 'Solar8000/HR', 'Solar8000/RR_CO2', 'BIS/BIS', 'Solar8000/PLETH_SPO2'], interval=1)

# %%
vf
# Out:
#        Solar8000/BT  Solar8000/HR  Solar8000/RR_CO2  BIS/BIS  \
# 0               NaN           NaN               NaN      NaN
# 1               NaN           NaN               NaN      NaN
# 2               NaN           NaN               NaN      NaN
# 3               NaN           NaN               NaN      0.0
# 4               NaN           NaN               NaN      0.0
# ...             ...           ...               ...      ...
# 20988           NaN           NaN               NaN      0.0
# 20989          23.5           NaN               NaN      0.0
# 20990           NaN           NaN               NaN      0.0
# 20991          23.5           NaN               NaN      0.0
# 20992           NaN           NaN               NaN      NaN
#
#        Solar8000/PLETH_SPO2
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# ...

# %%
vf = vf.reset_index()
vf = vf.rename(columns={"index": 'time',  "Solar8000/BT": "body temperature", 'BIS/BIS': 'Bispectral Index', 'Solar8000/RR_CO2': "Respiratory rate" })
# Solar8000/PLETH_SPO2 - Насыщение крови кислородом

# %%
vf = vf.dropna()

# %%
figure = px.line(vf, x="time", y="body temperature")
figure.show()

# %%
# x_list = vf.time.tolist()
# delta_t = 5
#
# x_list = x_list[0:20]
# print(x_list)
# print('-------------------')
# #

# %%
figure = px.line(vf, x="time", y="Bispectral Index")
figure.show()

# %%
figure = px.line(vf, x="time", y="Respiratory rate")
figure.show()

# %%
figure = px.line(vf, x="time", y="Solar8000/PLETH_SPO2")
figure.show()

# %%
import numpy as np
from scipy.fft import fft

x = np.array([1, 2, 3, 4])
res = fft(x)
print(res)
# Out:
# [10.-0.j -2.+2.j -2.-0.j -2.-2.j]

# %%
vf = vitaldb.VitalFile("0010.vital").to_pandas(['SNUADC/ECG_V5'], interval=1)
vf.dropna()
# Out:
# Empty DataFrame
# Columns: [SNUADC/ECG_V5]
# Index: []

# %%
vf = vf.rename(columns={"index": 'time' })

figure = px.line(vf, x="time", y="SNUADC/ECG_V5")
figure.show()

# %%
vf
# Out:
#         time  SNUADC/ECG_V5
# 0          0            NaN
# 1          1            NaN
# 2          2            NaN
# 3          3            NaN
# 4          4            NaN
# ...      ...            ...
# 20988  20988            NaN
# 20989  20989            NaN
# 20990  20990            NaN
# 20991  20991            NaN
# 20992  20992            NaN
#
# [20993 rows x 2 columns]
