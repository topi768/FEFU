# %% [markdown]
# есть ли диабет или нет

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train.csv')
df
# Out:
#             id  age  alcohol_consumption_per_week  \
# 0            0   31                             1
# 1            1   50                             2
# 2            2   32                             3
# 3            3   54                             3
# 4            4   54                             1
# ...        ...  ...                           ...
# 699995  699995   29                             1
# 699996  699996   46                             2
# 699997  699997   35                             1
# 699998  699998   49                             2
# 699999  699999   42                             4
#
#         physical_activity_minutes_per_week  diet_score  sleep_hours_per_day  \
# 0                                       45         7.7                  6.8
# 1                                       73         5.7                  6.5
# 2                                      158         8.5                  7.4
# ...

# %%
df = df.drop(['id'], axis=1)

# %%
df.isna().sum()
# Out:
# age                                   0
# alcohol_consumption_per_week          0
# physical_activity_minutes_per_week    0
# diet_score                            0
# sleep_hours_per_day                   0
# screen_time_hours_per_day             0
# bmi                                   0
# waist_to_hip_ratio                    0
# systolic_bp                           0
# diastolic_bp                          0
# heart_rate                            0
# cholesterol_total                     0
# hdl_cholesterol                       0
# ldl_cholesterol                       0
# triglycerides                         0
# gender                                0
# ethnicity                             0
# education_level                       0
# income_level                          0
# smoking_status                        0
# employment_status                     0
# family_history_diabetes               0
# hypertension_history                  0
# ...

# %%
for i in  df.columns.tolist():
    print(i + " " + str(df[i].max()))
# Out:
# age 89
# alcohol_consumption_per_week 9
# physical_activity_minutes_per_week 747
# diet_score 9.9
# sleep_hours_per_day 9.9
# screen_time_hours_per_day 16.5
# bmi 38.4
# waist_to_hip_ratio 1.05
# systolic_bp 163
# diastolic_bp 104
# heart_rate 101
# cholesterol_total 289
# hdl_cholesterol 90
# ldl_cholesterol 205
# triglycerides 290
# gender Other
# ethnicity White
# education_level Postgraduate
# income_level Upper-Middle
# smoking_status Never
# employment_status Unemployed
# family_history_diabetes 1
# hypertension_history 1
# cardiovascular_history 1
# diagnosed_diabetes 1.0

# %%
for i in  df.columns.tolist():
    print(i + " " + str(df[i].min()))
# Out:
# age 19
# alcohol_consumption_per_week 1
# physical_activity_minutes_per_week 1
# diet_score 0.1
# sleep_hours_per_day 3.1
# screen_time_hours_per_day 0.6
# bmi 15.1
# waist_to_hip_ratio 0.68
# systolic_bp 91
# diastolic_bp 51
# heart_rate 42
# cholesterol_total 117
# hdl_cholesterol 21
# ldl_cholesterol 51
# triglycerides 31
# gender Female
# ethnicity Asian
# education_level Graduate
# income_level High
# smoking_status Current
# employment_status Employed
# family_history_diabetes 0
# hypertension_history 0
# cardiovascular_history 0
# diagnosed_diabetes 0.0
