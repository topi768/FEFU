# %%
import re
import regex
from nltk.stem.snowball import SnowballStemmer
from collections import Counter

with open("Bible_txt.txt", "r", encoding="cp1251") as f:
    text = f.read()

emoji_re = regex.compile(r"[\p{So}\p{Cn}]+", flags=regex.UNICODE)
non_word_re = regex.compile(r"[^0-9\p{L}'\s]+", flags=regex.UNICODE)
multispace_re = re.compile(r"\s+")

stemmer = SnowballStemmer("russian")


text = text.lower()
text = non_word_re.sub(" ", text)
text = multispace_re.sub(" ", text).strip()
text = emoji_re.sub(" ", text)
cleaned = text

tokens = regex.findall(r"\p{L}[\p{L}']*", text, flags=regex.UNICODE)



def stem_tokens(tokens):
    # Д) Стемминг
    return [stemmer.stem(t) for t in tokens]


# text = ("Привет!!  Я СТРОКА 😊           - коты, кота и КОТИКИ любят "бегать"!!!  😎")

stems = stem_tokens(tokens)
#
# print("cleaned:", cleaned)
# print("stems:", stems)
bow = Counter(tokens)
print(bow.most_common(100)  )
# Out:
# [('и', 57462), ('в', 16276), ('не', 11879), ('его', 9357), ('на', 8969), ('что', 6315), ('он', 6047), ('я', 5860), ('с', 5430), ('их', 5388), ('от', 5046), ('из', 4584), ('к', 4340), ('как', 4340), ('сказал', 3769), ('господь', 3698), ('а', 3634), ('они', 3580), ('ты', 3557), ('ибо', 3421), ('все', 3187), ('по', 3121), ('но', 2907), ('чтобы', 2882), ('же', 2831), ('то', 2737), ('у', 2714), ('будет', 2539), ('когда', 2527), ('за', 2487), ('для', 2389), ('меня', 2387), ('ему', 2300), ('так', 2168), ('о', 2122), ('тебя', 2108), ('во', 2088), ('мне', 2034), ('бог', 1916), ('это', 1880), ('если', 1851), ('вы', 1801), ('им', 1777), ('вот', 1732), ('ее', 1674), ('тебе', 1672), ('пред', 1649), ('господа', 1634), ('кто', 1565), ('сын', 1496), ('которые', 1481), ('вас', 1443), ('него', 1419), ('них', 1406), ('было', 1390), ('всех', 1363), ('был', 1356), ('до', 1354), ('говорит', 1332), ('мы', 1315), ('который', 1310), ('день', 1291), ('ли', 1284), ('потому', 1273), ('царь', 1271), ('народ', 1250), ('будут', 1196), ('да', 1185), ('ни', 1161), ('ним', 1148), ('бога', 1137), ('вам', 1123), ('тогда', 1112), ('бы', 1074), ('есть', 1039), ('мой', 1037), ('над', 1010), ('своего', 1006), ('сынов', 951), ('были', 944), ('нас', 937), ('земле', 925), ('земли', 924), ('или', 922), ('землю', 919), ('против', 915), ('тот', 913), ('царя', 901), ('твоего', 899), ('она', 895), ('дом', 872), ('сына', 865), ('твой', 844), ('при', 828), ('твои', 818), ('господу', 808), ('своих', 803), ('того', 792), ('человек', 785), ('руки', 782)]
